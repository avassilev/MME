# %% [markdown]
# Като използвате стъпките от файл Data_processing.ipynb като шаблон, повторете анализа за оценката на общата факторна производителност (growth accounting частта от файла) с **тримесечни** данни за избрана от Вас икономика от Европейския съюз.
#
# - Използвайте наборите с данни `namq_10_gdp` и `namq_10_pe` от Евростат, като ги запазите локално с модификация на показания на лекцията код.
# - За тези набори от данни работете със сезонно и календарно изгладените серии (SCA).
# - Използвайте годишен коефициент на амортизация $\delta_a = 0.05$ и на тази основа аналитично изчислете тримесечен коефициент на амортизация $\delta$. За да направите пресмятанията, разгледайте ситуация, при която няма инвестиции. Тогава, ако $K_t$ е размерът на физическия капитал в тримесечие $t$, ще имаме
#   $$ K_{t+4} = (1-\delta_a)K_t $$ и $$ K_{t+1} = (1-\delta)K_t . $$ Последните две връзки позволяват $\delta$ да бъде изразен като функция на $\delta_a$.
# - Изобразете графично получения резултат за $a_t$.
#
# **Заданието се предава по имейл във вид на Jupyter notebook с кода и съответните обяснения. При необходимост ще бъдат поискани и файловете със свалените от Евростат данни, като методът на предаване ще бъде уточнен допълнително.**
